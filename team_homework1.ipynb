# %% [markdown]
# <a href="https://colab.research.google.com/github/HKyeol/team_study/blob/main/team_homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#plt.rc('axes', unicode_minus=False)
from IPython.display import set_matplotlib_formats

plt.rc('font', family='NanumBarunGothic') 


set_matplotlib_formats('retina')

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/상가(상권)정보_의료기관_201909.csv', low_memory = False)
#df.shape()
df.head(1)
# Out:
#      상가업소번호     상호명  지점명 상권업종대분류코드  ...  층정보  호정보          경도         위도
# 0  19956873  하나산부인과  NaN         S  ...  NaN  NaN  126.814295  37.336344
#
# [1 rows x 39 columns]

# %%
df.tail(1)
# Out:
#          상가업소번호           상호명  지점명 상권업종대분류코드  ...  층정보  호정보          경도        위도
# 91334  16109073  천안김안과천안역본점의원  NaN         S  ...  NaN  NaN  127.152651  36.80664
#
# [1 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   지점명        1346 non-null   object
#  3   상권업종대분류코드  91335 non-null  object
#  4   상권업종대분류명   91335 non-null  object
#  5   상권업종중분류코드  91335 non-null  object
#  6   상권업종중분류명   91335 non-null  object
#  7   상권업종소분류코드  91335 non-null  object
#  8   상권업종소분류명   91335 non-null  object
#  9   표준산업분류코드   86413 non-null  object
#  10  표준산업분류명    86413 non-null  object
#  11  시도코드       90956 non-null  float64
#  12  시도명        90956 non-null  object
#  13  시군구코드      90956 non-null  float64
#  14  시군구명       90956 non-null  object
#  15  행정동코드      91335 non-null  int64
#  16  행정동명       90956 non-null  object
#  17  법정동코드      91280 non-null  float64
#  18  법정동명       91280 non-null  object
# ...

# %%
df.isnull()
(df.isnull().sum())
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47291
# 호정보          75784
# 경도               0
# 위도               0
# dtype: int64

# %%
null_count = df.isnull().sum()
null_count.plot()

# %%
null_count.plot.bar()

# %%
null_count.plot.barh(figsize = (5,7))

# %%
df_null_count =  null_count.reset_index() # 데이터 프레임 형태로 보여줌
df_null_count.head()
# Out:
#        index      0
# 0     상가업소번호      0
# 1        상호명      0
# 2        지점명  89989
# 3  상권업종대분류코드      0
# 4   상권업종대분류명      0

# %%
df_null_count.columns = ['컬럼명','결측치 수']
df_null_count.head( )
# Out:
#          컬럼명  결측치 수
# 0     상가업소번호      0
# 1        상호명      0
# 2        지점명  89989
# 3  상권업종대분류코드      0
# 4   상권업종대분류명      0

# %%
df_null_count.sort_values(by = '결측치 수',ascending = False)
# 괄호 안에서 shift tap으로 옵션 보기 가능 코랩에선 안되네
# ascending = False 하면 결측치 많은 순으로 정렬
# Out:
#           컬럼명  결측치 수
# 2         지점명  89989
# 34        동정보  83929
# 28      건물부번지  80731
# 36        호정보  75784
# 35        층정보  47291
# 30        건물명  44882
# 23      지번부번지  19256
# 9    표준산업분류코드   4922
# 10    표준산업분류명   4922
# 11       시도코드    379
# 13      시군구코드    379
# 14       시군구명    379
# 16       행정동명    379
# 12        시도명    379
# 17      법정동코드     55
# 18       법정동명     55
# 32      구우편번호     12
# 33      신우편번호      2
# 29     건물관리번호      0
# 27      건물본번지      0
# 0      상가업소번호      0
# 31      도로명주소      0
# 25      도로명코드      0
# 37         경도      0
# 26        도로명      0
# 19       지번코드      0
# 24       지번주소      0
# 22      지번본번지      0
# 21      대지구분명      0
# 20     대지구분코드      0
# 1         상호명      0
# 15      행정동코드      0
# 8    상권업종소분류명      0
# 7   상권업종소분류코드      0
# 6    상권업종중분류명      0
# 5   상권업종중분류코드      0
# 4    상권업종대분류명      0
# 3   상권업종대분류코드      0
# 38         위도      0

# %%
df_null_count_top = df_null_count.sort_values(by = '결측치 수',ascending = False).head(10)
df_null_count_top
# Out:
#          컬럼명  결측치 수
# 2        지점명  89989
# 34       동정보  83929
# 28     건물부번지  80731
# 36       호정보  75784
# 35       층정보  47291
# 30       건물명  44882
# 23     지번부번지  19256
# 9   표준산업분류코드   4922
# 10   표준산업분류명   4922
# 11      시도코드    379

# %%
df['지점명'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    수지점
# Name: 지점명, dtype: object

# %%
drop_columns = df_null_count_top['컬럼명'].tolist()
drop_columns
# Out:
# ['지점명',
#  '동정보',
#  '건물부번지',
#  '호정보',
#  '층정보',
#  '건물명',
#  '지번부번지',
#  '표준산업분류코드',
#  '표준산업분류명',
#  '시도코드']

# %%
df[drop_columns].head()
# Out:
#    지점명  동정보  건물부번지  호정보  층정보      건물명  지번부번지 표준산업분류코드         표준산업분류명  시도코드
# 0  NaN  NaN    NaN  NaN  NaN  산호한양아파트    NaN   Q86201           일반 의원  41.0
# 1  NaN  NaN    NaN  NaN    4      NaN   14.0   Q86201           일반 의원  11.0
# 2  NaN  NaN    NaN  NaN  NaN    한라프라자    1.0   Q86201           일반 의원  41.0
# 3  NaN  NaN    NaN  NaN    5      NaN    1.0      NaN             NaN  26.0
# 4  수지점  NaN    NaN  NaN    1      NaN    2.0   G47811  의약품 및 의료용품 소매업  41.0

# %%
print(df.shape)
df = df.drop(drop_columns, axis = 1) # 0 = 행을 기준 drop, 1 = 열을 기준 drop 행열 01
print(df.shape) # 컬럼값 10개가 줄었다.
# Out:
# (91335, 39)
# (91335, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   상권업종대분류코드  91335 non-null  object
#  3   상권업종대분류명   91335 non-null  object
#  4   상권업종중분류코드  91335 non-null  object
#  5   상권업종중분류명   91335 non-null  object
#  6   상권업종소분류코드  91335 non-null  object
#  7   상권업종소분류명   91335 non-null  object
#  8   시도명        90956 non-null  object
#  9   시군구코드      90956 non-null  float64
#  10  시군구명       90956 non-null  object
#  11  행정동코드      91335 non-null  int64
#  12  행정동명       90956 non-null  object
#  13  법정동코드      91280 non-null  float64
#  14  법정동명       91280 non-null  object
#  15  지번코드       91335 non-null  int64
#  16  대지구분코드     91335 non-null  int64
#  17  대지구분명      91335 non-null  object
#  18  지번본번지      91335 non-null  int64
# ...

# %%
df['위도'].mean()
# Out:
# 36.62471119236673

# %%
df['위도'].median()
# Out:
# 37.23465231770329

# %%
df['위도'].max()
# Out:
# 38.499658570559795

# %%
df['위도'].min()
# Out:
# 33.2192896688307

# %%
df['위도'].describe()
# Out:
# count    91335.000000
# mean        36.624711
# std          1.041361
# min         33.219290
# 25%         35.811830
# 50%         37.234652
# 75%         37.507463
# max         38.499659
# Name: 위도, dtype: float64

# %%
df[['위도','경도']].describe()
# Out:
#                  위도            경도
# count  91335.000000  91335.000000
# mean      36.624711    127.487524
# std        1.041361      0.842877
# min       33.219290    124.717632
# 25%       35.811830    126.914297
# 50%       37.234652    127.084550
# 75%       37.507463    128.108919
# max       38.499659    130.909912

# %%
df.describe(include='number')
# Out:
#              상가업소번호          시도코드  ...            경도            위도
# count  9.133500e+04  90956.000000  ...  91335.000000  91335.000000
# mean   2.121818e+07     32.586712  ...    127.487524     36.624711
# std    5.042828e+06     13.045138  ...      0.842877      1.041361
# min    2.901108e+06     11.000000  ...    124.717632     33.219290
# 25%    2.001931e+07     26.000000  ...    126.914297     35.811830
# 50%    2.211900e+07     41.000000  ...    127.084550     37.234652
# 75%    2.480984e+07     43.000000  ...    128.108919     37.507463
# max    2.852470e+07     50.000000  ...    130.909912     38.499659
#
# [8 rows x 16 columns]

# %%
df.describe(include='object')
# Out:
#           상호명   지점명 상권업종대분류코드  ...   동정보    층정보    호정보
# count   91335  1346     91335  ...  7406  44044  15551
# unique  56910   858         1  ...   556     74    849
# top        리원  장례식장         S  ...     1      1      1
# freq      152    97     91335  ...  1571  15994   1286
#
# [4 rows x 23 columns]

# %%
df.describe(include='all')
# Out:
#               상가업소번호    상호명   지점명  ...    호정보            경도            위도
# count   9.133500e+04  91335  1346  ...  15551  91335.000000  91335.000000
# unique           NaN  56910   858  ...    849           NaN           NaN
# top              NaN     리원  장례식장  ...      1           NaN           NaN
# freq             NaN    152    97  ...   1286           NaN           NaN
# mean    2.121818e+07    NaN   NaN  ...    NaN    127.487524     36.624711
# std     5.042828e+06    NaN   NaN  ...    NaN      0.842877      1.041361
# min     2.901108e+06    NaN   NaN  ...    NaN    124.717632     33.219290
# 25%     2.001931e+07    NaN   NaN  ...    NaN    126.914297     35.811830
# 50%     2.211900e+07    NaN   NaN  ...    NaN    127.084550     37.234652
# 75%     2.480984e+07    NaN   NaN  ...    NaN    128.108919     37.507463
# max     2.852470e+07    NaN   NaN  ...    NaN    130.909912     38.499659
#
# [11 rows x 39 columns]

# %%
df['상권업종대분류명']
# Out:
# 0        의료
# 1        의료
# 2        의료
# 3        의료
# 4        의료
#          ..
# 91330    의료
# 91331    의료
# 91332    의료
# 91333    의료
# 91334    의료
# Name: 상권업종대분류명, Length: 91335, dtype: object

# %%
df['상권업종대분류명'].unique() # 중복제거하니 의료만 남음
# Out:
# array(['의료'], dtype=object)

# %%
df['상권업종대분류명'].nunique() # 중복제거하고 갯수세기
# Out:
# 1

# %%
df['상권업종중분류명']
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
df['상권업종중분류명'].unique()
# Out:
# array(['병원', '약국/한약방', '수의업', '유사의료업', '의료관련서비스업'], dtype=object)

# %%
df['상권업종중분류명'].nunique()
# Out:
# 5

# %%
df['상권업종소분류명'].unique()
# Out:
# array(['산부인과', '내과/외과', '신경외과', '기타병원', '약국', '동물병원', '한약방', '탕제원',
#        '정형/성형외과', '소아과', '이비인후과의원', '노인/치매병원', '언어치료', '수의업-종합', '한의원',
#        '치과의원', '침구원', '일반병원', '안과의원', '조산원', '한방병원', '종합병원', '유사의료업기타',
#        '응급구조대', '혈액원', '치과병원', '척추교정치료', '피부과', '비뇨기과', '치과기공소', '산후조리원',
#        '접골원', '수의업-기타', '제대혈'], dtype=object)

# %%
df['상권업종소분류명'].nunique()
# Out:
# 34

# %%
len(df['상권업종소분류명'].unique())
# Out:
# 34

# %%
df['시도명'].head()
# Out:
# 0      경기도
# 1    서울특별시
# 2      경기도
# 3    부산광역시
# 4      경기도
# Name: 시도명, dtype: object

# %%
df['시도명'].value_counts() # 카테고리 형태의 데이터 갯수 세기
# Out:
# 경기도        21374
# 서울특별시      18943
# 부산광역시       6473
# 경상남도        4973
# 인천광역시       4722
# 대구광역시       4597
# 경상북도        4141
# 전라북도        3894
# 충청남도        3578
# 전라남도        3224
# 광주광역시       3214
# 대전광역시       3067
# 충청북도        2677
# 강원도         2634
# 울산광역시       1997
# 제주특별자치도     1095
# 세종특별자치시      353
# Name: 시도명, dtype: int64

# %%
df['시도명'].value_counts(normalize = True) # 각각이 몇 %비율을 차지하는지 보여준다.
# Out:
# 경기도        0.234993
# 서울특별시      0.208266
# 부산광역시      0.071166
# 경상남도       0.054675
# 인천광역시      0.051915
# 대구광역시      0.050541
# 경상북도       0.045528
# 전라북도       0.042812
# 충청남도       0.039338
# 전라남도       0.035446
# 광주광역시      0.035336
# 대전광역시      0.033720
# 충청북도       0.029432
# 강원도        0.028959
# 울산광역시      0.021956
# 제주특별자치도    0.012039
# 세종특별자치시    0.003881
# Name: 시도명, dtype: float64

# %%
city.plot()

# %%
city.plot.barh()

# %%
city.plot.pie(figsize = (7,7)) # figsize 사이즈 조절

# %%
city_normalize.plot.pie(figsize = (7,7)) # figsize 사이즈 조절

# %% [markdown]
# seaborn에는 파이차트 없다.

# %%
sns.countplot(data=df,x='시도명') # x나 y 하나만 사용한다 고급통계를 그래프 내부에 사용 속도 느린게 단점

# %%
c = sns.countplot(data=df,y='시도명')

# %%
df['상권업종대분류명'].value_counts() # 결측치 제거하고 갯수센다
# Out:
# 의료    91335
# Name: 상권업종대분류명, dtype: int64

# %%
df['상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
df['상권업종중분류명'].value_counts(normalize=True)
# Out:
# 병원          0.665397
# 약국/한약방      0.229080
# 수의업         0.058280
# 유사의료업       0.041320
# 의료관련서비스업    0.005923
# Name: 상권업종중분류명, dtype: float64

# %%
c.plot()

# %%
c.plot.bar()

# %%
c.plot.bar(rot=0) # 누운 변수명 옆으로 돌리기

# %%
n
# Out:
# 병원          0.665397
# 약국/한약방      0.229080
# 수의업         0.058280
# 유사의료업       0.041320
# 의료관련서비스업    0.005923
# Name: 상권업종중분류명, dtype: float64

# %%
n.plot.pie()

# %%
df['상권업종소분류명']
# Out:
# 0           산부인과
# 1          내과/외과
# 2           신경외과
# 3           기타병원
# 4             약국
#           ...
# 91330         약국
# 91331      산후조리원
# 91332    노인/치매병원
# 91333        한의원
# 91334       안과의원
# Name: 상권업종소분류명, Length: 91335, dtype: object

# %%
df['상권업종소분류명'].value_counts()
# Out:
# 약국         18964
# 치과의원       13731
# 한의원        13211
# 내과/외과      11374
# 기타병원        4922
# 일반병원        3385
# 동물병원        3098
# 정형/성형외과     2562
# 소아과         2472
# 수의업-종합      2216
# 치과기공소       1724
# 이비인후과의원     1486
# 한약방         1442
# 피부과         1273
# 산부인과        1116
# 노인/치매병원     1055
# 안과의원        1042
# 비뇨기과         809
# 종합병원         762
# 치과병원         756
# 언어치료         664
# 유사의료업기타      629
# 탕제원          517
# 산후조리원        511
# 신경외과         421
# 한방병원         397
# 척추교정치료       338
# 침구원          154
# 혈액원          130
# 응급구조대        125
# 조산원           30
# 접골원            9
# 수의업-기타         9
# 제대혈            1
# Name: 상권업종소분류명, dtype: int64

# %%
c = df['상권업종소분류명'].value_counts()

# %%
c.plot.barh(figsize = (7,8),grid=True) # grid = 격자표시

# %%
df['상권업종중분류명']=='약국/한약방'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 91330     True
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종중분류명, Length: 91335, dtype: bool

# %%
df[df['상권업종중분류명']=='약국/한약방']
# Out:
#          상가업소번호        상호명 상권업종대분류코드  ...    신우편번호          경도         위도
# 4      20364049  더블유스토어수지점         S  ...  16837.0  127.095522  37.323528
# 6      20733252      춘산한약방         S  ...  24273.0  127.726905  37.880504
# 7      20582210      부부탕제원         S  ...  28726.0  127.499206  36.625355
# 10     21057519       민생약국         S  ...  50212.0  128.118615  35.575962
# 13     21217689     제중당한약방         S  ...  58429.0  126.630348  34.834080
# ...         ...        ...       ...  ...      ...         ...        ...
# 91312  16131397      큰나무약국         S  ...  10464.0  126.835684  37.655048
# 91321  16130841       복음약국         S  ...  42735.0  128.547352  35.836250
# 91322  16091491  설연화한복감성약방         S  ...   2034.0  127.078082  37.613194
# 91324  16109731      위례수약국         S  ...  13647.0  127.137870  37.465260
# 91330  16196725      온누리약국         S  ...  35240.0  127.389865  36.352728
#
# [20923 rows x 29 columns]

# %%
df_medical = df[df['상권업종중분류명']=='약국/한약방'].copy()
df_medical.head()
# Out:
#       상가업소번호        상호명 상권업종대분류코드  ...    신우편번호          경도         위도
# 4   20364049  더블유스토어수지점         S  ...  16837.0  127.095522  37.323528
# 6   20733252      춘산한약방         S  ...  24273.0  127.726905  37.880504
# 7   20582210      부부탕제원         S  ...  28726.0  127.499206  36.625355
# 10  21057519       민생약국         S  ...  50212.0  128.118615  35.575962
# 13  21217689     제중당한약방         S  ...  58429.0  126.630348  34.834080
#
# [5 rows x 29 columns]

# %%
df['상권업종대분류명']=='의료'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 91330    True
# 91331    True
# 91332    True
# 91333    True
# 91334    True
# Name: 상권업종대분류명, Length: 91335, dtype: bool

# %%
 df[df['상권업종대분류명']=='의료']
# Out:
#          상가업소번호           상호명 상권업종대분류코드  ...    신우편번호          경도         위도
# 0      19956873        하나산부인과         S  ...  15236.0  126.814295  37.336344
# 1      20024149      타워광명내과의원         S  ...   6292.0  127.053198  37.488742
# 2      20152277     조정현신경외과의원         S  ...  15066.0  126.734841  37.344955
# 3      20350610      한귀원정신과의원         S  ...  48266.0  129.115438  35.166872
# 4      20364049     더블유스토어수지점         S  ...  16837.0  127.095522  37.323528
# ...         ...           ...       ...  ...      ...         ...        ...
# 91330  16196725         온누리약국         S  ...  35240.0  127.389865  36.352728
# 91331  16192180            리원         S  ...  10503.0  126.830144  37.627530
# 91332  16127538       참좋은요양병원         S  ...  46294.0  129.082790  35.227138
# 91333  16108681       경희중앙한의원         S  ...   5303.0  127.143958  37.540993
# 91334  16109073  천안김안과천안역본점의원         S  ...  31127.0  127.152651  36.806640
#
# [91335 rows x 29 columns]

# %%
 df[df['상권업종대분류명']=='의료']['상권업종중분류명']
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
df.loc[df['상권업종대분류명']=='의료']['상권업종중분류명']
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
df.loc[df['상권업종대분류명']=='의료','상권업종중분류명']
# Out:
# 0              병원
# 1              병원
# 2              병원
# 3              병원
# 4          약국/한약방
#            ...
# 91330      약국/한약방
# 91331    의료관련서비스업
# 91332          병원
# 91333          병원
# 91334          병원
# Name: 상권업종중분류명, Length: 91335, dtype: object

# %%
df.loc[df['상권업종대분류명']=='의료','상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
m = df['상권업종대분류명']=='의료'
df.loc[m,'상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
df['상권업종중분류명'] == '유사의료업'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종중분류명, Length: 91335, dtype: bool

# %%
df[df['상권업종중분류명'] == '유사의료업']
# Out:
#          상가업소번호         상호명    지점명 상권업종대분류코드  ...  층정보   호정보          경도         위도
# 22     21013731    세종언어치료센터    NaN         S  ...    3   NaN  129.091662  35.246528
# 40     20933900     고려수지침학회    NaN         S  ...    5   NaN  128.684678  35.224113
# 97     21717820         청명원    NaN         S  ...    1   NaN  127.635740  36.768935
# 102    21865854    응급환자이송센터    NaN         S  ...    1   NaN  127.417693  36.321801
# 108    21914637  태화아동발달지원센터    NaN         S  ...    1   NaN  127.412725  36.312953
# ...         ...         ...    ...       ...  ...  ...   ...         ...        ...
# 91300  16131218     으뜸치과기공소    NaN         S  ...    2   NaN  128.084600  35.197029
# 91310  16199325     보령치과기공소    NaN         S  ...    4     5  127.010602  37.591455
# 91311  16199088       점프셈교실   홍현단과         S  ...  NaN   NaN  129.211755  35.865600
# 91319  16108560  씨앤디자인치과기공소    NaN         S  ...  NaN  1901  126.886122  37.475986
# ...

# %%
df[df['상권업종중분류명'] == '유사의료업'].shape
# Out:
# (3774, 39)

# %%
df['상호명']
# Out:
# 0              하나산부인과
# 1            타워광명내과의원
# 2           조정현신경외과의원
# 3            한귀원정신과의원
# 4           더블유스토어수지점
#              ...
# 91330           온누리약국
# 91331              리원
# 91332         참좋은요양병원
# 91333         경희중앙한의원
# 91334    천안김안과천안역본점의원
# Name: 상호명, Length: 91335, dtype: object

# %%
df['상호명'].value_counts()
# Out:
# 리원         152
# 온누리약국      149
# 경희한의원      141
# 우리약국       119
# 중앙약국       111
#           ...
# 인성당약국        1
# 인천세광병원       1
# 첨단리더스치과      1
# 성낙관성형외과      1
# 대산동물병원       1
# Name: 상호명, Length: 56910, dtype: int64

# %%
df['상호명'].value_counts().head()
# Out:
# 리원       152
# 온누리약국    149
# 경희한의원    141
# 우리약국     119
# 중앙약국     111
# Name: 상호명, dtype: int64

# %%
df['상호명'].value_counts().tail()
# Out:
# 인성당약국      1
# 인천세광병원     1
# 첨단리더스치과    1
# 성낙관성형외과    1
# 대산동물병원     1
# Name: 상호명, dtype: int64

# %%
df_medi = df[df['상권업종중분류명'] == '유사의료업']
df_medi['상호명'].value_counts()
# Out:
# 리원             32
# 고려수지침          22
# 대한적십자사         17
# 헌혈의집           12
# 고려수지침학회        10
#                ..
# 나린치과기공소         1
# 삼신치과기공소         1
# 대한척추외과학회        1
# ELI아동발달지원센터     1
# 바른척추체형          1
# Name: 상호명, Length: 2926, dtype: int64

# %%
df['상권업종소분류명']=='약국'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 91330     True
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종소분류명, Length: 91335, dtype: bool

# %%
df['시도명'] =='서울특별시'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333     True
# 91334    False
# Name: 시도명, Length: 91335, dtype: bool

# %%
(df['상권업종소분류명']=='약국') &(df['시도명']== '서울특별시')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Length: 91335, dtype: bool

# %%
df[(df['상권업종소분류명']=='약국') &(df['시도명']== '서울특별시')]
# Out:
#          상가업소번호        상호명  지점명 상권업종대분류코드  ...  층정보  호정보          경도         위도
# 33     20816709      이즈타워약  NaN         S  ...    1  NaN  127.028023  37.498656
# 51     20855710       진흥약국  NaN         S  ...  NaN  NaN  127.145055  37.534135
# 130    21589838      신세계약국  NaN         S  ...    1  NaN  127.092597  37.616424
# 136    22388303    메디팜한솔약국  NaN         S  ...    1  NaN  127.027513  37.556238
# 141    22412563        명약국  NaN         S  ...    1  NaN  127.060556  37.587349
# ...         ...        ...  ...       ...  ...  ...  ...         ...        ...
# 91239  16131547     우리이웃약국  NaN         S  ...    1  116  127.033908  37.594792
# 91275  16195709     더블유스토어  세계로         S  ...    1  NaN  126.884285  37.499936
# 91288  16131839      종각팜약국  NaN         S  ...    1  NaN  126.984930  37.569882
# 91301  16188650      온누리약국  우리네         S  ...  NaN  NaN  126.888070  37.484897
# 91322  16091491  설연화한복감성약방  NaN         S  ...  NaN  NaN  127.078082  37.613194
#
# ...

# %%
df_seoul_drug = df[(df['상권업종소분류명']=='약국') &(df['시도명']== '서울특별시')]
df_seoul_drug.shape
# Out:
# (3579, 29)

# %%
df_seoul_drug['시군구명']
# Out:
# 33        강남구
# 51        강동구
# 130       중랑구
# 136       성동구
# 141      동대문구
#          ...
# 91239     성북구
# 91275     구로구
# 91288     종로구
# 91301     구로구
# 91322     중랑구
# Name: 시군구명, Length: 3579, dtype: object

# %%
df_seoul_drug['시군구명'].value_counts()
# Out:
# 강남구     374
# 동대문구    261
# 광진구     212
# 서초구     191
# 송파구     188
# 노원구     169
# 성북구     160
# 은평구     151
# 영등포구    145
# 마포구     136
# 강서구     136
# 중랑구     129
# 서대문구    120
# 관악구     118
# 강동구     117
# 종로구     111
# 양천구     109
# 중구      106
# 강북구     104
# 구로구     102
# 동작구      96
# 성동구      88
# 용산구      87
# 금천구      85
# 도봉구      84
# Name: 시군구명, dtype: int64

# %%
c = df_seoul_drug['시군구명'].value_counts()
c.head()
# Out:
# 강남구     374
# 동대문구    261
# 광진구     212
# 서초구     191
# 송파구     188
# Name: 시군구명, dtype: int64

# %%
df_seoul_drug['시군구명'].value_counts(normalize = True)
# Out:
# 강남구     0.104498
# 동대문구    0.072925
# 광진구     0.059234
# 서초구     0.053367
# 송파구     0.052529
# 노원구     0.047220
# 성북구     0.044705
# 은평구     0.042191
# 영등포구    0.040514
# 마포구     0.037999
# 강서구     0.037999
# 중랑구     0.036044
# 서대문구    0.033529
# 관악구     0.032970
# 강동구     0.032691
# 종로구     0.031014
# 양천구     0.030455
# 중구      0.029617
# 강북구     0.029058
# 구로구     0.028500
# 동작구     0.026823
# 성동구     0.024588
# 용산구     0.024308
# 금천구     0.023750
# 도봉구     0.023470
# Name: 시군구명, dtype: float64

# %%
n = df_seoul_drug['시군구명'].value_counts(normalize = True)
n.head()
# Out:
# 강남구     0.104498
# 동대문구    0.072925
# 광진구     0.059234
# 서초구     0.053367
# 송파구     0.052529
# Name: 시군구명, dtype: float64

# %%
c.plot()

# %%
c.plot.bar()

# %%
c.plot.bar(rot=60) # 60도 기울이기

# %%
df['상권업종소분류명']=='종합병원'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91330    False
# 91331    False
# 91332    False
# 91333    False
# 91334    False
# Name: 상권업종소분류명, Length: 91335, dtype: bool

# %%
df[df['상권업종소분류명']=='종합병원']

# %%
df[(df['상권업종소분류명']=='종합병원')&(df['시도명']=='서울특별시')]

# %%
df_seoul_hospital = df[(df['상권업종소분류명']=='종합병원')&
                       (df['시도명']=='서울특별시')].copy()
df_seoul_hospital
# Out:
#          상가업소번호               상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 305    25155642            대진의료재단         S  ...  4944.0  127.088279  37.559048
# 353    20471487            홍익병원별관         S  ...  7937.0  126.862805  37.529213
# 385    20737057              SNUH         S  ...  6236.0  127.035825  37.499630
# 1917   23210677  평화드림여의도성모병원의료기매장         S  ...  7345.0  126.936693  37.518296
# 2461   20024045                한양         S  ...  4763.0  127.041325  37.559469
# ...         ...               ...       ...  ...     ...         ...        ...
# 71991  28505952      서울성모병원응급의료센터         S  ...  6591.0  127.005841  37.502382
# 76508  12292992             라마르의원         S  ...  5335.0  127.127466  37.538485
# 90492  16031909     가톨릭대학교여의도성모병원         S  ...  4537.0  126.986758  37.563662
# 90581  16332576              씨엠병원         S  ...  7301.0  126.903857  37.518807
# 90788  16162338            성베드로병원         S  ...  6271.0  127.039567  37.485604
#
# ...

# %%
df_seoul_hospital['시군구명'].value_counts()
# Out:
# 강남구     15
# 영등포구     8
# 광진구      6
# 서초구      6
# 중구       5
# 강동구      5
# 송파구      5
# 강북구      4
# 서대문구     4
# 양천구      4
# 도봉구      4
# 성북구      3
# 성동구      2
# 관악구      2
# 중랑구      2
# 금천구      2
# 동대문구     2
# 노원구      2
# 구로구      2
# 종로구      2
# 강서구      2
# 용산구      1
# 은평구      1
# 마포구      1
# 동작구      1
# Name: 시군구명, dtype: int64

# %%
df_seoul_hospital['상호명'].str.contains('종합병원') # 종합병원 텍스트를 포함하는 애들만 가져옴
# Out:
# 305      False
# 353      False
# 385      False
# 1917     False
# 2461     False
#          ...
# 71991    False
# 76508    False
# 90492    False
# 90581    False
# 90788    False
# Name: 상호명, Length: 91, dtype: bool

# %%
df_seoul_hospital[~df_seoul_hospital['상호명'].str.contains('종합병원') ] # 종합병ㄹ원 아닌 애들만 가져옴
# Out:
#          상가업소번호               상호명     지점명  ...  호정보          경도         위도
# 305    25155642            대진의료재단     NaN  ...  NaN  127.088279  37.559048
# 353    20471487            홍익병원별관     NaN  ...  NaN  126.862805  37.529213
# 385    20737057              SNUH     NaN  ...  NaN  127.035825  37.499630
# 1917   23210677  평화드림여의도성모병원의료기매장     NaN  ...  NaN  126.936693  37.518296
# 2461   20024045                한양     NaN  ...  NaN  127.041325  37.559469
# ...         ...               ...     ...  ...  ...         ...        ...
# 71991  28505952      서울성모병원응급의료센터  응급의료센터  ...  NaN  127.005841  37.502382
# 76508  12292992             라마르의원     NaN  ...  NaN  127.127466  37.538485
# 90492  16031909     가톨릭대학교여의도성모병원     NaN  ...  NaN  126.986758  37.563662
# 90581  16332576              씨엠병원     NaN  ...  NaN  126.903857  37.518807
# 90788  16162338            성베드로병원     NaN  ...  NaN  127.039567  37.485604
#
# [91 rows x 39 columns]

# %%
df_seoul_hospital.loc[~df_seoul_hospital['상호명'].str.contains('종합병원'),
                      '상호명']
# Out:
# 305                대진의료재단
# 353                홍익병원별관
# 385                  SNUH
# 1917     평화드림여의도성모병원의료기매장
# 2461                   한양
#                ...
# 71991        서울성모병원응급의료센터
# 76508               라마르의원
# 90492       가톨릭대학교여의도성모병원
# 90581                씨엠병원
# 90788              성베드로병원
# Name: 상호명, Length: 91, dtype: object

# %%
df_seoul_hospital.loc[~df_seoul_hospital['상호명'].str.contains('종합병원'),
                      '상호명'].unique()
# Out:
# array(['대진의료재단', '홍익병원별관', 'SNUH', '평화드림여의도성모병원의료기매장', '한양', '백산의료재단친구병원',
#        '서울보훈병원', '서울성모병원장례식장꽃배달', '서울대학교병원', '알콜중독및정신질환상담소',
#        '강남성모병원장례식장꽃배달', '제일병원', '이랜드클리닉', '사랑나눔의료재단', '우울증센터', '성심의료재단',
#        '다나의료재단', '서울아산병원신관', '원자력병원장례식장', '국민의원', '고려대학교구로병원', '학교법인일송학원',
#        '삼성의료원장례식장', '희명스포츠의학센터인공신장실', '연세대학교의과대학강남세브란스', '국립정신병원',
#        '코아클리닉', '수서제일의원', '사랑의의원', '한국전력공사부속한일병원', '신촌연세병원', '창동제일의원',
#        '영동세브란스병원', '제일성심의원', '삼성의료재단강북삼성태', '서울시립보라매병원', '서울이의원',
#        '서울대학교병원비상계획외래', '평화드림서울성모병원의료', '홍익병원', '사랑나눔의료재단서', '독일의원',
#        '서울연합의원', '우신향병원', '동부제일병원', '아산재단금강병원', '명곡안연구소', '아산재단서울중앙병원',
#        '메디힐특수여객', '삼성생명공익재단삼성서', '성광의료재단차병원', '한국건강관리협회서울특',
#        '정해복지부설한신메디피아', '성베드로병원', '성애의료재단', '실로암의원', 'Y&T성모마취과', '광진성모의원',
#        '서울현대의원', '이노신경과의원', '송정훼밀리의원', '서울중앙의원', '영남의료재단', '인제대학교서울백병원',
#        '한국필의료재단', '세브란스의원', '가톨릭대학교성바오로병원장례식장', '서울연세의원', '사랑의병원',
#        '성삼의료재단미즈메디병원', '씨엠충무병원', '성신의원', '원진재단부설녹색병원', '송파제일의원',
# ...

# %%
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('꽃배달')]
# Out:
#         상가업소번호            상호명  지점명 상권업종대분류코드  ... 층정보  호정보          경도         위도
# 2803  20895655  서울성모병원장례식장꽃배달  NaN         S  ...   1  NaN  127.000682  37.498257
# 4644  22020310  강남성모병원장례식장꽃배달  NaN         S  ...   1  NaN  127.001756  37.499095
#
# [2 rows x 39 columns]

# %%
df_seoul_hospital[df_seoul_hospital['상호명'].str.contains('의료기')]
# Out:
#         상가업소번호               상호명  지점명 상권업종대분류코드  ... 층정보  호정보          경도         위도
# 1917  23210677  평화드림여의도성모병원의료기매장  NaN         S  ...   1  NaN  126.936693  37.518296
#
# [1 rows x 39 columns]

# %%
df_seoul_hospital[
    df_seoul_hospital['상호명'].str.contains('꽃배달|의료기|장례식장|상담소|어린이집')]
# Out:
#          상가업소번호                상호명   지점명  ...  호정보          경도         위도
# 1917   23210677   평화드림여의도성모병원의료기매장   NaN  ...  NaN  126.936693  37.518296
# 2803   20895655      서울성모병원장례식장꽃배달   NaN  ...  NaN  127.000682  37.498257
# 4431   21781516       알콜중독및정신질환상담소   NaN  ...  NaN  127.046203  37.657046
# 4644   22020310      강남성모병원장례식장꽃배달   NaN  ...  NaN  127.001756  37.499095
# 7938   20625484          원자력병원장례식장  장례식장  ...  NaN  127.082670  37.628808
# 10283  20024377          삼성의료원장례식장  장례식장  ...  NaN  127.089579  37.490334
# 47008  21738670   가톨릭대학교성바오로병원장례식장  장례식장  ...  NaN  127.043471  37.579246
# 60645  27670796         서울성모병원어린이집   NaN  ...  NaN  127.005841  37.502382
# 70177  11537223  한림대학교부속한강성심병원장례식장  장례식장  ...  NaN  126.909676  37.523168
#
# [9 rows x 39 columns]

# %%
df_seoul_hospital[ 
    df_seoul_hospital['상호명'].str.contains('꽃배달|의료기|장례식장|상담소|어린이집')].index #인덱스만 제거
# Out:
# Int64Index([1917, 2803, 4431, 4644, 7938, 10283, 47008, 60645, 70177], dtype='int64')

# %%
drop_row = df_seoul_hospital[ 
    df_seoul_hospital['상호명'].str.contains('꽃배달|의료기|장례식장|상담소|어린이집')].index
drop_row = drop_row.tolist() # 리스트 형태로 변환
drop_row
# Out:
# [1917, 2803, 4431, 4644, 7938, 10283, 47008, 60645, 70177]

# %%
df_seoul_hospital[
    df_seoul_hospital['상호명'].str.endswith('의원')] # 의원으로 끝나는 애들 가져오기

# %%
drop_row2 = df_seoul_hospital[
    df_seoul_hospital['상호명'].str.endswith('의원')].index
drop_row2 = drop_row2.tolist()
drop_row2
# Out:
# [8479,
#  12854,
#  13715,
#  14966,
#  16091,
#  18047,
#  20200,
#  20415,
#  30706,
#  32889,
#  34459,
#  34720,
#  35696,
#  37251,
#  45120,
#  49626,
#  51575,
#  55133,
#  56320,
#  56404,
#  56688,
#  57551,
#  62113,
#  76508]

# %%
drop_row = drop_row + drop_row2
len(drop_row)
# Out:
# 33

# %%
print(df_seoul_hospital.shape)
df_seoul_hospital = df_seoul_hospital.drop(drop_row, axis = 0) # axis 0 이면 행기준 1이면 열기준
print(df_seoul_hospital.shape)
# Out:
# (91, 29)
# (58, 29)

# %%
df_seoul_hospital['시군구명'].value_counts()
# Out:
# 강남구     12
# 영등포구     6
# 중구       5
# 양천구      4
# 광진구      3
# 서초구      3
# 강동구      3
# 송파구      3
# 중랑구      2
# 종로구      2
# 서대문구     2
# 구로구      2
# 금천구      2
# 성북구      2
# 마포구      1
# 관악구      1
# 도봉구      1
# 용산구      1
# 성동구      1
# 강서구      1
# 동작구      1
# Name: 시군구명, dtype: int64

# %%
df_seoul_hospital['시군구명'].value_counts().plot.bar()

# %%
plt.figure(figsize = (15,4))
sns.countplot(data = df_seoul_hospital, x = '시군구명')

# %%
plt.figure(figsize = (15,4))
sns.countplot(data = df_seoul_hospital, x = '시군구명', order = df_seoul_hospital['시군구명'].value_counts().index)

# %%
 df_seoul_hospital['상호명'].unique()
# Out:
# array(['대진의료재단', '홍익병원별관', 'SNUH', '한양', '백산의료재단친구병원', '서울보훈병원',
#        '서울대학교병원', '제일병원', '이랜드클리닉', '사랑나눔의료재단', '우울증센터', '성심의료재단',
#        '다나의료재단', '서울아산병원신관', '고려대학교구로병원', '학교법인일송학원', '희명스포츠의학센터인공신장실',
#        '연세대학교의과대학강남세브란스', '국립정신병원', '코아클리닉', '한국전력공사부속한일병원', '신촌연세병원',
#        '영동세브란스병원', '삼성의료재단강북삼성태', '서울시립보라매병원', '서울대학교병원비상계획외래',
#        '평화드림서울성모병원의료', '홍익병원', '사랑나눔의료재단서', '우신향병원', '동부제일병원', '아산재단금강병원',
#        '명곡안연구소', '아산재단서울중앙병원', '메디힐특수여객', '삼성생명공익재단삼성서', '성광의료재단차병원',
#        '한국건강관리협회서울특', '정해복지부설한신메디피아', '성베드로병원', '성애의료재단', 'Y&T성모마취과',
#        '영남의료재단', '인제대학교서울백병원', '한국필의료재단', '사랑의병원', '성삼의료재단미즈메디병원',
#        '씨엠충무병원', '원진재단부설녹색병원', '강남센트럴병원', '우리들병원', '건국대학교병원', '서울적십자병원',
#        '서울성모병원응급의료센터', '가톨릭대학교여의도성모병원', '씨엠병원'], dtype=object)

# %%
df_seoul = df[df['시도명']=='서울특별시'].copy()
print(df_seoul.shape)
# Out:
# (18943, 39)

# %%
df_seoul['시도명'].value_counts()
# Out:
# 서울특별시    18943
# Name: 시도명, dtype: int64

# %%
df_seoul['시군구명'].value_counts().head()
# Out:
# 강남구     3120
# 서초구     1491
# 동대문구    1152
# 송파구     1021
# 광진구      935
# Name: 시군구명, dtype: int64

# %%
df_seoul['시군구명'].value_counts().plot.bar(figsize=(10,4),rot=30)

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df_seoul,x='시군구명')

# %%
df_seoul[['경도','위도','시군구명']]
# Out:
#                경도         위도  시군구명
# 1      127.053198  37.488742   강남구
# 8      127.028531  37.522223   강남구
# 9      127.027878  37.514144   강남구
# 31     127.126507  37.537333   강동구
# 33     127.028023  37.498656   강남구
# ...           ...        ...   ...
# 91318  127.045802  37.583788  동대문구
# 91319  126.886122  37.475986   금천구
# 91320  127.057988  37.629326   노원구
# 91322  127.078082  37.613194   중랑구
# 91333  127.143958  37.540993   강동구
#
# [18943 rows x 3 columns]

# %%
df_seoul[['경도','위도','시군구명']].plot.scatter(x='경도',y='위도',figsize=(8,7),grid=True)

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(data=df_seoul,x='경도',y='위도',hue='시군구명') # hue : 색깔

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(data=df_seoul,x='경도',y='위도',hue='상권업종중분류명') # hue : 색깔

# %%
plt.figure(figsize=(16,12))
sns.scatterplot(data=df,x='경도',y='위도',hue='시도명') # 전국 데이터

# %%
import folium
df_seoul_hospital['위도'].mean()
# Out:
# 37.52972276355594

# %%
df_seoul_hospital['경도'].mean()
# Out:
# 126.9963589356625

# %%
df_seoul_hospital.head(1)
# Out:
#        상가업소번호     상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 305  25155642  대진의료재단         S  ...  4944.0  127.088279  37.559048
#
# [1 rows x 29 columns]

# %%
df_seoul_hospital.tail(1)
# Out:
#          상가업소번호     상호명 상권업종대분류코드  ...   신우편번호          경도         위도
# 90788  16162338  성베드로병원         S  ...  6271.0  127.039567  37.485604
#
# [1 rows x 29 columns]

# %%
map = folium.Map(location=[df_seoul_hospital['위도'].mean(),df_seoul_hospital['경도'].mean()],
           zoom_start=12)
for n in df_seoul_hospital.index:
    name = df_seoul_hospital.loc[n,'상호명']
    address = df_seoul_hospital.loc[n,'도로명주소']
    popup = f"{name}-{address}"
    location = [df_seoul_hospital.loc[n,'위도'],df_seoul_hospital.loc[n,'경도']]
    folium.Marker(
        location = location,
        popup = popup
        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
